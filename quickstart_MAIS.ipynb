# %% [markdown]
# <a href="https://colab.research.google.com/github/intelligent-environments-lab/CityLearn/blob/master/examples/quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # QuickStart
#
# Install the latest CityLearn version from PyPi with the :code:`pip` command:

# %%
# !pip install CityLearn
# Out:
# Requirement already satisfied: CityLearn in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (2.1.2)
# Requirement already satisfied: gym>=0.21.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (0.26.2)
# Requirement already satisfied: matplotlib in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (3.7.5)
# Requirement already satisfied: numpy>=1.21.6 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (1.24.4)
# Requirement already satisfied: pandas==1.3.5 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (1.3.5)
# Requirement already satisfied: scikit-learn==1.0.2 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (1.0.2)
# Requirement already satisfied: simplejson in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (3.19.2)
# Requirement already satisfied: torch>=1.12.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (2.3.1)
# Requirement already satisfied: torchvision>=0.13.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from CityLearn) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from pandas==1.3.5->CityLearn) (2.9.0)
# Requirement already satisfied: pytz>=2017.3 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from pandas==1.3.5->CityLearn) (2024.1)
# Requirement already satisfied: scipy>=1.1.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from scikit-learn==1.0.2->CityLearn) (1.10.1)
# Requirement already satisfied: joblib>=0.11 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from scikit-learn==1.0.2->CityLearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from scikit-learn==1.0.2->CityLearn) (3.5.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from gym>=0.21.0->CityLearn) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from gym>=0.21.0->CityLearn) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from gym>=0.21.0->CityLearn) (8.0.0)
# Requirement already satisfied: filelock in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (4.12.2)
# Requirement already satisfied: sympy in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (1.12.1)
# Requirement already satisfied: networkx in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (3.1)
# Requirement already satisfied: jinja2 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (3.1.4)
# Requirement already satisfied: fsspec in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (2024.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torch>=1.12.0->CityLearn) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.12.0->CityLearn) (12.5.40)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from torchvision>=0.13.0->CityLearn) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from matplotlib->CityLearn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from matplotlib->CityLearn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from matplotlib->CityLearn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from matplotlib->CityLearn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from matplotlib->CityLearn) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from matplotlib->CityLearn) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from matplotlib->CityLearn) (6.4.0)
# Requirement already satisfied: zipp>=0.5 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gym>=0.21.0->CityLearn) (3.19.2)
# Requirement already satisfied: six>=1.5 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas==1.3.5->CityLearn) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from jinja2->torch>=1.12.0->CityLearn) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages (from sympy->torch>=1.12.0->CityLearn) (1.3.0)

# %% [markdown]
# ## CityLearn Control Agents

# %% [markdown]
# ### No Control (Baseline)
#
# Run the following to simulate an environment where the storage systems and heat pumps are not controlled (baseline). The storage actions prescribed will be 0.0 and the heat pump will have no action, i.e. `None`, causing it to deliver the ideal load in the building time series files:

# %%
from citylearn.agents.base import BaselineAgent as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_1', central_agent=True)
model = Agent(env)

# step through environment and apply agent actions
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# /home/Mengxin/anaconda3/envs/citylearn/lib/python3.8/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# name                                     Building_1  Building_2  Building_3  \
# cost_function
# all_time_peak_average                           NaN         NaN         NaN
# annual_normalized_unserved_energy_total       0.000       0.000       0.000
# carbon_emissions_total                        1.000       1.000       1.000
# cost_total                                    1.000       1.000       1.000
# daily_one_minus_load_factor_average             NaN         NaN         NaN
# daily_peak_average                              NaN         NaN         NaN
# discomfort_cold_delta_average                 1.699       0.044       0.671
# discomfort_cold_delta_maximum                 4.741       1.772       3.466
# discomfort_cold_delta_minimum                 0.000       0.000       0.000
# discomfort_cold_proportion                    0.396       0.000       0.082
# discomfort_hot_delta_average                  0.018       0.515       0.077
# discomfort_hot_delta_maximum                  1.332       2.360       1.502
# discomfort_hot_delta_minimum                  0.000       0.000       0.000
# discomfort_hot_proportion                     0.000       0.015       0.000
# discomfort_proportion                         0.396       0.015       0.082
# electricity_consumption_total                 1.000       1.000       1.000
# monthly_one_minus_load_factor_average           NaN         NaN         NaN
# ramping_average                                 NaN         NaN         NaN
# zero_net_energy                               1.000       1.000       1.000
#
# name                                     District
# cost_function
# all_time_peak_average                       1.000
# annual_normalized_unserved_energy_total     0.000
# carbon_emissions_total                      1.000
# cost_total                                  1.000
# daily_one_minus_load_factor_average         1.000
# daily_peak_average                          1.000
# discomfort_cold_delta_average               0.805
# discomfort_cold_delta_maximum               3.326
# discomfort_cold_delta_minimum               0.000
# discomfort_cold_proportion                  0.159
# discomfort_hot_delta_average                0.203
# discomfort_hot_delta_maximum                1.731
# discomfort_hot_delta_minimum                0.000
# discomfort_hot_proportion                   0.005
# discomfort_proportion                       0.164
# electricity_consumption_total               1.000
# monthly_one_minus_load_factor_average       1.000
# ramping_average                             1.000
# zero_net_energy                             1.000

# %% [markdown]
# ### Centralized RBC
# Run the following to simulate an environment controlled by centralized RBC agent for a single episode:

# %%
from citylearn.agents.rbc import BasicRBC as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_1', central_agent=True)
model = Agent(env)

# step through environment and apply agent actions
observations, _ = env.reset()

while not env.terminated:
    actions = model.predict(observations)
    observations, reward, info, terminated, truncated = env.step(actions)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                     Building_1  Building_2  Building_3  \
# cost_function
# all_time_peak_average                           NaN         NaN         NaN
# annual_normalized_unserved_energy_total      -0.000       0.000      -0.000
# carbon_emissions_total                        1.986       1.927       1.728
# cost_total                                    1.923       1.872       1.703
# daily_one_minus_load_factor_average             NaN         NaN         NaN
# daily_peak_average                              NaN         NaN         NaN
# discomfort_cold_delta_average                 9.938       3.535       3.222
# discomfort_cold_delta_maximum                13.562       9.931       5.399
# discomfort_cold_delta_minimum                 0.000       0.000       0.000
# discomfort_cold_proportion                    0.982       0.914       0.975
# discomfort_hot_delta_average                  0.000       0.001       0.000
# discomfort_hot_delta_maximum                  0.013       0.356       0.016
# discomfort_hot_delta_minimum                  0.000       0.000       0.000
# discomfort_hot_proportion                     0.000       0.000       0.000
# discomfort_proportion                         0.982       0.914       0.975
# electricity_consumption_total                 1.984       1.954       1.743
# monthly_one_minus_load_factor_average           NaN         NaN         NaN
# ramping_average                                 NaN         NaN         NaN
# zero_net_energy                               2.011       1.954       1.743
#
# name                                     District
# cost_function
# all_time_peak_average                       1.179
# annual_normalized_unserved_energy_total    -0.000
# carbon_emissions_total                      1.880
# cost_total                                  1.833
# daily_one_minus_load_factor_average         0.723
# daily_peak_average                          1.325
# discomfort_cold_delta_average               5.565
# discomfort_cold_delta_maximum               9.630
# discomfort_cold_delta_minimum               0.000
# discomfort_cold_proportion                  0.957
# discomfort_hot_delta_average                0.000
# discomfort_hot_delta_maximum                0.128
# discomfort_hot_delta_minimum                0.000
# discomfort_hot_proportion                   0.000
# discomfort_proportion                       0.957
# electricity_consumption_total               1.894
# monthly_one_minus_load_factor_average       0.863
# ramping_average                             0.968
# zero_net_energy                             1.903

# %% [markdown]
# ### Decentralized-Independent SAC
#
# Run the following to simulate an environment controlled by decentralized-independent SAC agents for 1 training episode:

# %%
from citylearn.agents.sac import SAC as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=False)
model = Agent(env)

# train
model.learn(episodes=2, deterministic_finish=True)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.013       0.013
# carbon_emissions_total                              0.954       0.980
# cost_total                                          0.917       0.940
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       2.006       0.921
# discomfort_cold_delta_maximum                       6.514       4.565
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.473       0.325
# discomfort_hot_delta_average                        0.223       0.547
# discomfort_hot_delta_maximum                        4.617       6.220
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.032       0.153
# discomfort_proportion                               0.505       0.478
# electricity_consumption_total                       0.964       0.998
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.733       0.500
# power_outage_normalized_unserved_energy_total       0.634       0.651
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.980       1.000
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.950
# annual_normalized_unserved_energy_total             0.013     0.013
# carbon_emissions_total                              0.958     0.964
# cost_total                                          0.927     0.928
# daily_one_minus_load_factor_average                   NaN     0.938
# daily_peak_average                                    NaN     0.934
# discomfort_cold_delta_average                       0.873     1.267
# discomfort_cold_delta_maximum                       2.974     4.685
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.235     0.344
# discomfort_hot_delta_average                        0.302     0.358
# discomfort_hot_delta_maximum                        3.978     4.938
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.030     0.072
# discomfort_proportion                               0.265     0.416
# electricity_consumption_total                       0.973     0.978
# monthly_one_minus_load_factor_average                 NaN     0.993
# one_minus_thermal_resilience_proportion             0.133     0.456
# power_outage_normalized_unserved_energy_total       0.598     0.627
# ramping_average                                       NaN     0.883
# zero_net_energy                                     0.974     0.985

# %% [markdown]
# ### Decentralized-Cooperative MARLISA
#
# Run the following to simulate an environment controlled by decentralized-cooperative MARLISA agents for 1 training episodes:

# %%
from citylearn.agents.marlisa import MARLISA as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_1', central_agent=False)
model = Agent(env)

# train
model.learn(episodes=20, deterministic_finish=True)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                     Building_1  Building_2  Building_3  \
# cost_function
# all_time_peak_average                           NaN         NaN         NaN
# annual_normalized_unserved_energy_total       0.000      -0.000       0.000
# carbon_emissions_total                        1.009       1.033       1.016
# cost_total                                    0.986       1.021       0.998
# daily_one_minus_load_factor_average             NaN         NaN         NaN
# daily_peak_average                              NaN         NaN         NaN
# discomfort_cold_delta_average                 1.941       0.064       0.496
# discomfort_cold_delta_maximum                 9.584       1.324       3.796
# discomfort_cold_delta_minimum                 0.000       0.000       0.000
# discomfort_cold_proportion                    0.412       0.000       0.085
# discomfort_hot_delta_average                  0.747       0.270       0.467
# discomfort_hot_delta_maximum                  5.469       2.873       3.080
# discomfort_hot_delta_minimum                  0.000       0.000       0.000
# discomfort_hot_proportion                     0.177       0.030       0.080
# discomfort_proportion                         0.589       0.030       0.165
# electricity_consumption_total                 0.986       1.035       1.006
# monthly_one_minus_load_factor_average           NaN         NaN         NaN
# ramping_average                                 NaN         NaN         NaN
# zero_net_energy                               0.994       1.034       1.006
#
# name                                     District
# cost_function
# all_time_peak_average                       0.876
# annual_normalized_unserved_energy_total     0.000
# carbon_emissions_total                      1.019
# cost_total                                  1.002
# daily_one_minus_load_factor_average         0.992
# daily_peak_average                          0.995
# discomfort_cold_delta_average               0.833
# discomfort_cold_delta_maximum               4.901
# discomfort_cold_delta_minimum               0.000
# discomfort_cold_proportion                  0.166
# discomfort_hot_delta_average                0.495
# discomfort_hot_delta_maximum                3.807
# discomfort_hot_delta_minimum                0.000
# discomfort_hot_proportion                   0.095
# discomfort_proportion                       0.261
# electricity_consumption_total               1.009
# monthly_one_minus_load_factor_average       0.966
# ramping_average                             0.970
# zero_net_energy                             1.011

# %%
from citylearn.agents.marlisa import MARLISA as Agent
from citylearn.citylearn import CityLearnEnv

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_1', central_agent=False)
model = Agent(env)

# train
model.learn(episodes=2, deterministic_finish=True)

# test
kpis = model.env.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# name                                     Building_1  Building_2  Building_3  \
# cost_function
# all_time_peak_average                           NaN         NaN         NaN
# annual_normalized_unserved_energy_total       0.000       0.000       0.000
# carbon_emissions_total                        0.958       0.975       0.958
# cost_total                                    0.920       0.936       0.927
# daily_one_minus_load_factor_average             NaN         NaN         NaN
# daily_peak_average                              NaN         NaN         NaN
# discomfort_cold_delta_average                 1.979       0.922       0.883
# discomfort_cold_delta_maximum                 6.465       4.569       2.980
# discomfort_cold_delta_minimum                 0.000       0.000       0.000
# discomfort_cold_proportion                    0.461       0.321       0.241
# discomfort_hot_delta_average                  0.220       0.525       0.291
# discomfort_hot_delta_maximum                  4.690       6.232       3.600
# discomfort_hot_delta_minimum                  0.000       0.000       0.000
# discomfort_hot_proportion                     0.036       0.146       0.027
# discomfort_proportion                         0.498       0.466       0.268
# electricity_consumption_total                 0.967       0.992       0.972
# monthly_one_minus_load_factor_average           NaN         NaN         NaN
# ramping_average                                 NaN         NaN         NaN
# zero_net_energy                               0.978       0.992       0.972
#
# name                                     District
# cost_function
# all_time_peak_average                       0.950
# annual_normalized_unserved_energy_total     0.000
# carbon_emissions_total                      0.964
# cost_total                                  0.927
# daily_one_minus_load_factor_average         0.931
# daily_peak_average                          0.921
# discomfort_cold_delta_average               1.262
# discomfort_cold_delta_maximum               4.671
# discomfort_cold_delta_minimum               0.000
# discomfort_cold_proportion                  0.341
# discomfort_hot_delta_average                0.345
# discomfort_hot_delta_maximum                4.841
# discomfort_hot_delta_minimum                0.000
# discomfort_hot_proportion                   0.070
# discomfort_proportion                       0.411
# electricity_consumption_total               0.977
# monthly_one_minus_load_factor_average       0.993
# ramping_average                             0.888
# zero_net_energy                             0.981

# %% [markdown]
# ## Other Standard Reinforcement Learning Libraries

# %% [markdown]
# ### Stable Baselines3 Reinforcement Learning Algorithms
#
# Install the latest version of Stable Baselines3:

# %%
# !pip install stable-baselines3

# %% [markdown]
# Before the environment is ready for use in Stable Baselines3, it needs to be wrapped. Firstly, wrap the environment using the `NormalizedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.NormalizedObservationWrapper)) to ensure that observations served to the agent are min-max normalized between [0, 1] and cyclical observations e.g. hour, are encoded using the cosine transformation.
#
# Next, we wrap with the `StableBaselines3Wrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.StableBaselines3Wrapper)) that ensures observations, actions and rewards are served in manner that is compatible with Stable Baselines3 interface.
#
# > ⚠️ **NOTE**: `central_agent` in the `env` must be `True` when using Stable Baselines3  as it does not support multi-agents.

# %%
from stable_baselines3.sac import SAC as Agent
from citylearn.citylearn import CityLearnEnv
from citylearn.wrappers import NormalizedObservationWrapper, StableBaselines3Wrapper

# initialize
env = CityLearnEnv('citylearn_challenge_2023_phase_2_local_evaluation', central_agent=True)
env = NormalizedObservationWrapper(env)
env = StableBaselines3Wrapper(env)
model = Agent('MlpPolicy', env)

# train
episodes = 2
model.learn(total_timesteps=env.unwrapped.time_steps*episodes)

# test
observations, _ = env.reset()

while not env.unwrapped.terminated:
    actions, _ = model.predict(observations, deterministic=True)
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# 2024-04-01 20:37:07,558	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-04-01 20:37:08,286	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.012
# carbon_emissions_total                              0.396       0.449
# cost_total                                          0.375       0.413
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       0.000       0.004
# discomfort_cold_delta_maximum                       0.124       0.581
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.000       0.000
# discomfort_hot_delta_average                        9.465       7.146
# discomfort_hot_delta_maximum                       16.783      14.850
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.982       0.978
# discomfort_proportion                               0.982       0.978
# electricity_consumption_total                       0.401       0.453
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             1.000       1.000
# power_outage_normalized_unserved_energy_total       0.570       0.509
# ramping_average                                       NaN         NaN
# zero_net_energy                                     0.275       0.362
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     0.834
# annual_normalized_unserved_energy_total             0.014     0.014
# carbon_emissions_total                              0.501     0.449
# cost_total                                          0.471     0.419
# daily_one_minus_load_factor_average                   NaN     1.316
# daily_peak_average                                    NaN     0.709
# discomfort_cold_delta_average                       0.001     0.002
# discomfort_cold_delta_maximum                       0.372     0.359
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.000     0.000
# discomfort_hot_delta_average                        8.046     8.219
# discomfort_hot_delta_maximum                       14.003    15.212
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.978     0.979
# discomfort_proportion                               0.978     0.979
# electricity_consumption_total                       0.508     0.454
# monthly_one_minus_load_factor_average                 NaN     1.126
# one_minus_thermal_resilience_proportion             1.000     1.000
# power_outage_normalized_unserved_energy_total       0.555     0.545
# ramping_average                                       NaN     0.974
# zero_net_energy                                     0.453     0.363

# %% [markdown]
# ### RLlib
#
# Install the latest version of RLlib:

# %%
# !pip install "ray[rllib]"

# %% [markdown]
# We advise that you include the `ClippedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.ClippedObservationWrapper)) wrapper when working with RLlib so that observations are always clipped within the observation space before sending to the agent if not, out-of-bound observations will raise a `ValueError` and terminate the training.
#
# We also wrap the environment with `NormalizedObservationWrapper` (see [docs](https://www.citylearn.net/api/citylearn.wrappers.html#citylearn.wrappers.NormalizedObservationWrapper)) to ensure that observations served to the agent are min-max normalized between [0, 1] and cyclical observations e.g. hour, are encoded using the cosine transformation.
#
# RLlib supports both [single-agent and multi-agent algorithms](https://docs.ray.io/en/latest/rllib/rllib-algorithms.html). See below for an example for either case.

# %% [markdown]
# ####  Single Agent
#
# The single-agent interface for RLlib is the `RLlibSingleAgentWrapper` wrapper.

# %%
import warnings
from citylearn.wrappers import ClippedObservationWrapper, NormalizedObservationWrapper, RLlibSingleAgentWrapper
from ray.rllib.algorithms.sac import SACConfig as Config

warnings.filterwarnings('ignore', category=DeprecationWarning)

# initialize
env_config = {
    'env_kwargs': {
        'schema': 'citylearn_challenge_2023_phase_2_local_evaluation',
    },
    'wrappers': [
        NormalizedObservationWrapper, 
        ClippedObservationWrapper
    ]
}
config = (
    Config()
    .environment(RLlibSingleAgentWrapper, env_config=env_config)
)
model = config.build()

# train
for i in range(2):
    _ = model.train()

# test
env = RLlibSingleAgentWrapper(env_config)
observations, _ = env.reset()

while not env.unwrapped.terminated:
    actions = model.compute_single_action(observations, explore=False)
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# 2024-04-01 20:53:15,333	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.016
# carbon_emissions_total                              1.632       1.598
# cost_total                                          1.572       1.548
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       7.743       2.896
# discomfort_cold_delta_maximum                      12.215       8.302
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.968       0.733
# discomfort_hot_delta_average                        0.013       0.093
# discomfort_hot_delta_maximum                        2.547       5.028
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.003       0.017
# discomfort_proportion                               0.971       0.750
# electricity_consumption_total                       1.643       1.626
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.800       0.571
# power_outage_normalized_unserved_energy_total       0.781       0.796
# ramping_average                                       NaN         NaN
# zero_net_energy                                     1.687       1.643
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.063
# annual_normalized_unserved_energy_total             0.014     0.015
# carbon_emissions_total                              1.459     1.563
# cost_total                                          1.427     1.516
# daily_one_minus_load_factor_average                   NaN     0.740
# daily_peak_average                                    NaN     1.166
# discomfort_cold_delta_average                       2.563     4.401
# discomfort_cold_delta_maximum                       5.262     8.593
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.757     0.819
# discomfort_hot_delta_average                        0.013     0.039
# discomfort_hot_delta_maximum                        3.506     3.694
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.008
# discomfort_proportion                               0.760     0.827
# electricity_consumption_total                       1.479     1.583
# monthly_one_minus_load_factor_average                 NaN     0.891
# one_minus_thermal_resilience_proportion             0.267     0.546
# power_outage_normalized_unserved_energy_total       0.708     0.762
# ramping_average                                       NaN     0.885
# zero_net_energy                                     1.488     1.606

# %% [markdown]
# #### Multi-agent
#
# The multi-agent interface for RLlib is the `RLlibMultiAgentEnv` wrapper.

# %%
import warnings
from citylearn.wrappers import ClippedObservationWrapper, NormalizedObservationWrapper, RLlibMultiAgentEnv
from ray.rllib.algorithms.sac import SACConfig as Config
from ray.rllib.policy.policy import PolicySpec

warnings.filterwarnings('ignore', category=DeprecationWarning)

# initialize
env_config = {
    'env_kwargs': {
        'schema': 'citylearn_challenge_2023_phase_2_local_evaluation',
    },
    'wrappers': [
        NormalizedObservationWrapper, 
        ClippedObservationWrapper
    ]
}
config = (
    Config()
    .environment(RLlibMultiAgentEnv, env_config=env_config)
    .multi_agent(
        policies={a: PolicySpec() for a in RLlibMultiAgentEnv(env_config)._agent_ids},
        policy_mapping_fn=lambda agent_id, episode, worker, **kwargs: agent_id,
    )
)
model = config.build()

# train
for i in range(2):
    _ = model.train()

# test
env = RLlibMultiAgentEnv(env_config)
observations, _ = env.reset()

while not env.terminated:
    actions = {p: model.compute_single_action(o, policy_id=p, explore=False) for p, o in observations.items()}
    observations, _, _, _, _ = env.step(actions)

kpis = env.unwrapped.evaluate()
kpis = kpis.pivot(index='cost_function', columns='name', values='value').round(3)
kpis = kpis.dropna(how='all')
display(kpis)
# Out:
# 2024-04-01 20:56:03,937	WARNING util.py:62 -- Install gputil for GPU system monitoring.
# name                                           Building_1  Building_2  \
# cost_function
# all_time_peak_average                                 NaN         NaN
# annual_normalized_unserved_energy_total             0.015       0.016
# carbon_emissions_total                              1.639       1.599
# cost_total                                          1.579       1.548
# daily_one_minus_load_factor_average                   NaN         NaN
# daily_peak_average                                    NaN         NaN
# discomfort_cold_delta_average                       7.789       2.896
# discomfort_cold_delta_maximum                      12.260       8.308
# discomfort_cold_delta_minimum                       0.000       0.000
# discomfort_cold_proportion                          0.968       0.731
# discomfort_hot_delta_average                        0.013       0.093
# discomfort_hot_delta_maximum                        2.521       5.046
# discomfort_hot_delta_minimum                        0.000       0.000
# discomfort_hot_proportion                           0.003       0.017
# discomfort_proportion                               0.971       0.748
# electricity_consumption_total                       1.650       1.626
# monthly_one_minus_load_factor_average                 NaN         NaN
# one_minus_thermal_resilience_proportion             0.800       0.571
# power_outage_normalized_unserved_energy_total       0.782       0.797
# ramping_average                                       NaN         NaN
# zero_net_energy                                     1.695       1.643
#
# name                                           Building_3  District
# cost_function
# all_time_peak_average                                 NaN     1.063
# annual_normalized_unserved_energy_total             0.014     0.015
# carbon_emissions_total                              1.462     1.566
# cost_total                                          1.431     1.519
# daily_one_minus_load_factor_average                   NaN     0.739
# daily_peak_average                                    NaN     1.168
# discomfort_cold_delta_average                       2.566     4.417
# discomfort_cold_delta_maximum                       5.261     8.610
# discomfort_cold_delta_minimum                       0.000     0.000
# discomfort_cold_proportion                          0.759     0.819
# discomfort_hot_delta_average                        0.013     0.039
# discomfort_hot_delta_maximum                        3.506     3.691
# discomfort_hot_delta_minimum                        0.000     0.000
# discomfort_hot_proportion                           0.003     0.008
# discomfort_proportion                               0.762     0.827
# electricity_consumption_total                       1.482     1.586
# monthly_one_minus_load_factor_average                 NaN     0.890
# one_minus_thermal_resilience_proportion             0.267     0.546
# power_outage_normalized_unserved_energy_total       0.708     0.762
# ramping_average                                       NaN     0.885
# zero_net_energy                                     1.491     1.609
